# %% [markdown]
# # Basic Exercises on Data Importing - Understanding - Manipulating - Analysis - Visualization

# %% [markdown]
# ## Section-1: The pupose of the below exercises (1-7) is to create dictionary and convert into dataframes, how to diplay etc...
# ## The below exercises required to create data

# %% [markdown]
# ### 1. Import the necessary libraries (pandas, numpy, datetime, re etc)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import re

# set the graphs to show in the jupyter notebook
# %matplotlib inline

# set seabor graphs to a better style
sns.set(style="ticks")

# %% [markdown]
# ### 2. Run the below line of code to create a dictionary and this will be used for below exercises

# %%
raw_data = {"name": ['Bulbasaur', 'Charmander','Squirtle','Caterpie'],
            "evolution": ['Ivysaur','Charmeleon','Wartortle','Metapod'],
            "type": ['grass', 'fire', 'water', 'bug'],
            "hp": [45, 39, 44, 45],
            "pokedex": ['yes', 'no','yes','no']                        
            }

# %% [markdown]
# ### 3. Assign it to a object called pokemon and it should be a pandas DataFrame

# %%
pokemon=pd.DataFrame(raw_data)

# %%
pokemon
# Out:
#          name   evolution   type  hp pokedex
# 0   Bulbasaur     Ivysaur  grass  45     yes
# 1  Charmander  Charmeleon   fire  39      no
# 2    Squirtle   Wartortle  water  44     yes
# 3    Caterpie     Metapod    bug  45      no

# %% [markdown]
# ### 4. If the DataFrame columns are in alphabetical order, change the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon=pokemon.loc[:,['name','type','hp','evolution','pokedex']]
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ### 5. Add another column called place, and insert places (lakes, parks, hills, forest etc) of your choice.

# %%
pokemon.insert(5,'place',['lakes','parks','hills','forest'])

# %%
pokemon
# Out:
#          name   type  hp   evolution pokedex   place
# 0   Bulbasaur  grass  45     Ivysaur     yes   lakes
# 1  Charmander   fire  39  Charmeleon      no   parks
# 2    Squirtle  water  44   Wartortle     yes   hills
# 3    Caterpie    bug  45     Metapod      no  forest

# %% [markdown]
# ### 6. Display the data type of each column

# %%
pokemon.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex      object
# place        object
# dtype: object

# %% [markdown]
# ### 7. Display the info of dataframe

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4 non-null      object
#  1   type       4 non-null      object
#  2   hp         4 non-null      int64
#  3   evolution  4 non-null      object
#  4   pokedex    4 non-null      object
#  5   place      4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 320.0+ bytes

# %% [markdown]
# ## Section-2: The pupose of the below exercise (8-20) is to understand deleting data with pandas.
# ## The below exercises required to use wine.data

# %% [markdown]
# ### 8. Import the dataset *wine.txt* from the folder and assign it to a object called wine
#
# Please note that the original data text file doesn't contain any header. Please ensure that when you import the data, you should use a suitable argument so as to avoid data getting imported as header.

# %%
wine=pd.read_csv('C:/users/hp/wine.txt')
wine
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# 3    2.93   735
# 4    2.85  1450
# ..    ...   ...
# 172  1.74   740
# 173  1.56   750
# 174  1.56   835
# 175  1.62   840
# 176  1.60   560
#
# [177 rows x 14 columns]

# %% [markdown]
# ### 9. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine=wine.drop(columns=['1','2.43','2.8','.28','5.64','3.92','1065'])

# %%
wine
# Out:
#      14.23  1.71  15.6  127  3.06  2.29  1.04
# 0    13.20  1.78  11.2  100  2.76  1.28  1.05
# 1    13.16  2.36  18.6  101  3.24  2.81  1.03
# 2    14.37  1.95  16.8  113  3.49  2.18  0.86
# 3    13.24  2.59  21.0  118  2.69  1.82  1.04
# 4    14.20  1.76  15.2  112  3.39  1.97  1.05
# ..     ...   ...   ...  ...   ...   ...   ...
# 172  13.71  5.65  20.5   95  0.61  1.06  0.64
# 173  13.40  3.91  23.0  102  0.75  1.41  0.70
# 174  13.27  4.28  20.0  120  0.69  1.35  0.59
# 175  13.17  2.59  20.0  120  0.68  1.46  0.60
# 176  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 10. Assign the columns as below:
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine=wine.rename(columns={'14.23':'alcohol',
                    '1.71':'malic_acid',
                    '15.6':'alcalinity_of_ash ',
                    '127':'magnesium',
                    '3.06':'flavanoids',
                    '2.29':'proanthocyanins ',
                    '1.04':'hue'})
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash   magnesium  flavanoids  \
# 0      13.20        1.78                11.2        100        2.76
# 1      13.16        2.36                18.6        101        3.24
# 2      14.37        1.95                16.8        113        3.49
# 3      13.24        2.59                21.0        118        2.69
# 4      14.20        1.76                15.2        112        3.39
# ..       ...         ...                 ...        ...         ...
# 172    13.71        5.65                20.5         95        0.61
# 173    13.40        3.91                23.0        102        0.75
# 174    13.27        4.28                20.0        120        0.69
# 175    13.17        2.59                20.0        120        0.68
# 176    14.13        4.10                24.5         96        0.76
#
#      proanthocyanins    hue
# 0                1.28  1.05
# 1                2.81  1.03
# 2                2.18  0.86
# 3                1.82  1.04
# 4                1.97  1.05
# ..                ...   ...
# 172              1.06  0.64
# 173              1.41  0.70
# 174              1.35  0.59
# 175              1.46  0.60
# 176              1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 11. Set the values of the first 3 values from alcohol column as NaN

# %%
wine.alcohol.loc[0:2]=np.nan
wine
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23364\2110138955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine.alcohol.loc[0:2]=np.nan
#      alcohol  malic_acid  alcalinity_of_ash   magnesium  flavanoids  \
# 0        NaN        1.78                11.2        100        2.76
# 1        NaN        2.36                18.6        101        3.24
# 2        NaN        1.95                16.8        113        3.49
# 3      13.24        2.59                21.0        118        2.69
# 4      14.20        1.76                15.2        112        3.39
# ..       ...         ...                 ...        ...         ...
# 172    13.71        5.65                20.5         95        0.61
# 173    13.40        3.91                23.0        102        0.75
# 174    13.27        4.28                20.0        120        0.69
# 175    13.17        2.59                20.0        120        0.68
# 176    14.13        4.10                24.5         96        0.76
#
#      proanthocyanins    hue
# 0                1.28  1.05
# 1                2.81  1.03
# 2                2.18  0.86
# 3                1.82  1.04
# 4                1.97  1.05
# ..                ...   ...
# 172              1.06  0.64
# 173              1.41  0.70
# 174              1.35  0.59
# 175              1.46  0.60
# 176              1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 12. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[[3,4], 'magnesium']=np.nan
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash   magnesium  flavanoids  \
# 0        NaN        1.78                11.2      100.0        2.76
# 1        NaN        2.36                18.6      101.0        3.24
# 2        NaN        1.95                16.8      113.0        3.49
# 3      13.24        2.59                21.0        NaN        2.69
# 4      14.20        1.76                15.2        NaN        3.39
# ..       ...         ...                 ...        ...         ...
# 172    13.71        5.65                20.5       95.0        0.61
# 173    13.40        3.91                23.0      102.0        0.75
# 174    13.27        4.28                20.0      120.0        0.69
# 175    13.17        2.59                20.0      120.0        0.68
# 176    14.13        4.10                24.5       96.0        0.76
#
#      proanthocyanins    hue
# 0                1.28  1.05
# 1                2.81  1.03
# 2                2.18  0.86
# 3                1.82  1.04
# 4                1.97  1.05
# ..                ...   ...
# 172              1.06  0.64
# 173              1.41  0.70
# 174              1.35  0.59
# 175              1.46  0.60
# 176              1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 13. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.loc[0:2,'alcohol']=10

# %%
wine.loc[[3,4],'magnesium']=[10,100]

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash   magnesium  flavanoids  \
# 0      10.00        1.78                11.2      100.0        2.76
# 1      10.00        2.36                18.6      101.0        3.24
# 2      10.00        1.95                16.8      113.0        3.49
# 3      13.24        2.59                21.0       10.0        2.69
# 4      14.20        1.76                15.2      100.0        3.39
# ..       ...         ...                 ...        ...         ...
# 172    13.71        5.65                20.5       95.0        0.61
# 173    13.40        3.91                23.0      102.0        0.75
# 174    13.27        4.28                20.0      120.0        0.69
# 175    13.17        2.59                20.0      120.0        0.68
# 176    14.13        4.10                24.5       96.0        0.76
#
#      proanthocyanins    hue
# 0                1.28  1.05
# 1                2.81  1.03
# 2                2.18  0.86
# 3                1.82  1.04
# 4                1.97  1.05
# ..                ...   ...
# 172              1.06  0.64
# 173              1.41  0.70
# 174              1.35  0.59
# 175              1.46  0.60
# 176              1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 14. Count the number of missing values in all columns.

# %%
wine.isnull().count()
# Out:
# alcohol               177
# malic_acid            177
# alcalinity_of_ash     177
# magnesium             177
# flavanoids            177
# proanthocyanins       177
# hue                   177
# dtype: int64

# %% [markdown]
# ### 15.  Create an array of 10 random numbers up until 10 and save it.

# %%
a1=np.random.randint(0,11,10)
list(a1)
# Out:
# [3, 1, 7, 1, 7, 4, 8, 2, 8, 6]

# %% [markdown]
# ### 16.  Set the rows corresponding to the random numbers to NaN in the column *alcohol*

# %%
wine.loc[a1,'alcohol']=np.NaN
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash   magnesium  flavanoids  \
# 0      10.00        1.78                11.2      100.0        2.76
# 1        NaN        2.36                18.6      101.0        3.24
# 2        NaN        1.95                16.8      113.0        3.49
# 3        NaN        2.59                21.0       10.0        2.69
# 4        NaN        1.76                15.2      100.0        3.39
# ..       ...         ...                 ...        ...         ...
# 172    13.71        5.65                20.5       95.0        0.61
# 173    13.40        3.91                23.0      102.0        0.75
# 174    13.27        4.28                20.0      120.0        0.69
# 175    13.17        2.59                20.0      120.0        0.68
# 176    14.13        4.10                24.5       96.0        0.76
#
#      proanthocyanins    hue
# 0                1.28  1.05
# 1                2.81  1.03
# 2                2.18  0.86
# 3                1.82  1.04
# 4                1.97  1.05
# ..                ...   ...
# 172              1.06  0.64
# 173              1.41  0.70
# 174              1.35  0.59
# 175              1.46  0.60
# 176              1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 17.  How many missing values do we have now?

# %%
wine.isnull().count()
# Out:
# alcohol               177
# malic_acid            177
# alcalinity_of_ash     177
# magnesium             177
# flavanoids            177
# proanthocyanins       177
# hue                   177
# dtype: int64

# %% [markdown]
# ### 18. Print only the non-null values in alcohol

# %%
wine.loc[~wine.alcohol.isnull(),'alcohol']
# Out:
# 0      10.00
# 5      14.39
# 9      14.10
# 10     14.12
# 11     13.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 170, dtype: float64

# %% [markdown]
# ### 19. Delete the rows that contain missing values

# %%
wine=wine.dropna(axis=0)

# %% [markdown]
# ### 20.  Reset the index, so it starts with 0 again

# %%
wine.reset_index()
# Out:
#      index  alcohol  malic_acid  alcalinity_of_ash   magnesium  flavanoids  \
# 0        0    10.00        1.78                11.2      100.0        2.76
# 1        5    14.39        1.87                14.6       96.0        2.52
# 2        9    14.10        2.16                18.0      105.0        3.32
# 3       10    14.12        1.48                16.8       95.0        2.43
# 4       11    13.75        1.73                16.0       89.0        2.76
# ..     ...      ...         ...                 ...        ...         ...
# 165    172    13.71        5.65                20.5       95.0        0.61
# 166    173    13.40        3.91                23.0      102.0        0.75
# 167    174    13.27        4.28                20.0      120.0        0.69
# 168    175    13.17        2.59                20.0      120.0        0.68
# 169    176    14.13        4.10                24.5       96.0        0.76
#
#      proanthocyanins    hue
# 0                1.28  1.05
# 1                1.98  1.02
# 2                2.38  1.25
# 3                1.57  1.17
# 4                1.81  1.15
# ..                ...   ...
# 165              1.06  0.64
# 166              1.41  0.70
# 167              1.35  0.59
# 168              1.46  0.60
# 169              1.35  0.61
#
# [170 rows x 8 columns]

# %% [markdown]
# ## Section-3: The pupose of the below exercise (21-27) is to understand ***filtering & sorting*** data from dataframe.
# ## The below exercises required to use chipotle.tsv

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Import the dataset directly from this link (https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and create dataframe called chipo

# %%
chipo=pd.read_csv('C:/users/hp/chipotle.txt',sep='\t')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### 21. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo.loc[chipo.item_price>10.00].loc[:,'item_name'].count()
# Out:
# 1130

# %%
chipo.loc[:,'item_price']=chipo.loc[:,'item_price'].apply(lambda x:x.replace('$',''))
chipo.loc[:,'item_price']=chipo.loc[:,'item_price'].astype('float')

# %% [markdown]
# ### 22. Print the Chipo Dataframe & info about data frame

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
# [4622 rows x 5 columns]

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %% [markdown]
# ### 23. What is the price of each item?
# - Delete the duplicates in item_name and quantity
# - Print a data frame with only two columns `item_name` and `item_price`
# - Sort the values from the most to less expensive

# %%
chipo.loc[:,['item_name','item_price']]=chipo.drop_duplicates(subset=['item_name','item_price'])
chipo.loc[:,['item_name','item_price']]
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                                    NaN         NaN
# 4618                                    NaN         NaN
# 4619                                    NaN         NaN
# 4620                                    NaN         NaN
# 4621                                    NaN         NaN
#
# [4622 rows x 2 columns]

# %%
chipo.sort_values(by='item_price',ascending=False).loc[:,['item_name','item_price']].reset_index()
# Out:
#       index                     item_name  item_price
# 0      3598  Chips and Fresh Tomato Salsa       44.25
# 1      3480                 Carnitas Bowl       35.25
# 2      1254               Chicken Burrito       35.00
# 3      3601                Veggie Burrito       33.75
# 4       409                  Chicken Bowl       32.94
# ...     ...                           ...         ...
# 4617   4617                           NaN         NaN
# 4618   4618                           NaN         NaN
# 4619   4619                           NaN         NaN
# 4620   4620                           NaN         NaN
# 4621   4621                           NaN         NaN
#
# [4622 rows x 3 columns]

# %% [markdown]
# ### 24. Sort by the name of the item

# %%
chipo.sort_values(by='item_name',ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 298        129         1  6 Pack Soft Drink
# 4510      1793         1      Barbacoa Bowl
# 3195      1278         1      Barbacoa Bowl
# 95          42         1      Barbacoa Bowl
# ...        ...       ...                ...
# 4617      1833         1                NaN
# 4618      1833         1                NaN
# 4619      1834         1                NaN
# 4620      1834         1                NaN
# 4621      1834         1                NaN
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 298                                            [Sprite]        6.49
# 4510                                        [Guacamole]       11.49
# 3195  [Fresh Tomato (Mild), [Lettuce, Black Beans, R...        8.69
# 95    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...        9.25
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...         NaN
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...         NaN
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         NaN
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...         NaN
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         NaN
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### 25. What was the quantity of the most expensive item ordered?

# %%
chipo.sort_values(by='item_price',ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### 26. How many times were a Veggie Salad Bowl ordered?

# %%
chipo.loc[chipo.item_name=='Veggie Salad Bowl']
# Out:
#      order_id  quantity          item_name  \
# 186        83         1  Veggie Salad Bowl
# 960       394         1  Veggie Salad Bowl
#
#                                     choice_description  item_price
# 186  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 960  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75

# %% [markdown]
# ### 27. How many times people orderd more than one Canned Soda?

# %%
#chipo.loc[chipo.item_name=='Canned Soda']
chipo.loc[(chipo.item_name=='Canned Soda') & (chipo.quantity>1)]
# Out:
#       order_id  quantity    item_name choice_description  item_price
# 18           9         2  Canned Soda           [Sprite]        2.18
# 2235       901         4  Canned Soda           [Sprite]        4.36

# %% [markdown]
# ## Section-4: The purpose of the below exercises is to understand how to perform aggregations of data frame
# ## The below exercises (28-33) required to use occupation.csv

# %% [markdown]
# ###  28. Import the dataset occupation.csv and assign object as users

# %%
users=pd.read_csv('C:/users/hp/occupation.csv')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator     2215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### 29. Discover what is the mean age per occupation

# %%
round(users.groupby('occupation')['age'].mean(),0)
# Out:
# occupation
# administrator    39.0
# artist           31.0
# doctor           44.0
# educator         42.0
# engineer         36.0
# entertainment    29.0
# executive        39.0
# healthcare       42.0
# homemaker        33.0
# lawyer           37.0
# librarian        40.0
# marketing        38.0
# none             27.0
# other            35.0
# programmer       33.0
# retired          63.0
# salesman         36.0
# scientist        36.0
# student          22.0
# technician       33.0
# writer           36.0
# Name: age, dtype: float64

# %% [markdown]
# ### 30. Discover the Male ratio per occupation and sort it from the most to the least.
#
# Use numpy.where() to encode gender column.

# %%
users.loc[:,'MailRatio']=np.where(users.gender=='M','Male','Female')
users.groupby('occupation')['MailRatio'].count().sort_values(axis=0,ascending=False)
# Out:
# occupation
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: MailRatio, dtype: int64

# %% [markdown]
# ### 31. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation')['age'].agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### 32. For each combination of occupation and gender, calculate the mean age

# %%
round(users.groupby(['occupation','gender'])['age'].mean(),0)
# Out:
# occupation     gender
# administrator  F         41.0
#                M         37.0
# artist         F         30.0
#                M         32.0
# doctor         M         44.0
# educator       F         39.0
#                M         43.0
# engineer       F         30.0
#                M         37.0
# entertainment  F         31.0
#                M         29.0
# executive      F         44.0
#                M         38.0
# healthcare     F         40.0
#                M         45.0
# homemaker      F         34.0
#                M         23.0
# lawyer         F         40.0
#                M         36.0
# librarian      F         40.0
#                M         40.0
# marketing      F         37.0
#                M         38.0
# none           F         36.0
#                M         19.0
# other          F         35.0
#                M         34.0
# programmer     F         32.0
#                M         33.0
# retired        F         70.0
#                M         63.0
# salesman       F         27.0
#                M         39.0
# scientist      F         28.0
#                M         36.0
# student        F         21.0
#                M         23.0
# technician     F         38.0
#                M         33.0
# writer         F         38.0
#                M         35.0
# Name: age, dtype: float64

# %% [markdown]
# ### 33.  For each occupation present the percentage of women and men

# %%
round(users.groupby('occupation')['gender'].count()/len(users)*100,0)
# Out:
# occupation
# administrator     8.0
# artist            3.0
# doctor            1.0
# educator         10.0
# engineer          7.0
# entertainment     2.0
# executive         3.0
# healthcare        2.0
# homemaker         1.0
# lawyer            1.0
# librarian         5.0
# marketing         3.0
# none              1.0
# other            11.0
# programmer        7.0
# retired           1.0
# salesman          1.0
# scientist         3.0
# student          21.0
# technician        3.0
# writer            5.0
# Name: gender, dtype: float64

# %% [markdown]
# ## Section-6: The purpose of the below exercises is to understand how to use lambda-apply-functions
# ## The below exercises (34-41) required to use student-mat.csv and student-por.csv files

# %% [markdown]
# ### 34. Import the datasets *student-mat* and *student-por* and append them and assigned object as df

# %%
st1=pd.read_csv('C:/users/hp/student-mat.csv')

st2=pd.read_csv('C:/users/hp/student-por.csv ')

# %%
df=st1.append(st2)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23364\3374381992.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=st1.append(st2)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [1044 rows x 33 columns]

# %% [markdown]
# ### 35. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df.loc[:,'school':'guardian']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian
# 0    course   mother
# 1    course   father
# 2     other   mother
# 3      home   mother
# 4      home   father
# ..      ...      ...
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother
#
# [1044 rows x 12 columns]

# %% [markdown]
# ### 36. Create a lambda function that captalize strings (example: if we give at_home as input function and should give At_home as output.

# %%
#df.Mjob=[a.capitalize() for a in df.Mjob] 
# Or

df.Mjob=df.Mjob.apply(lambda x:x.capitalize())
df.Mjob
# Out:
# 0       At_home
# 1       At_home
# 2       At_home
# 3        Health
# 4         Other
#          ...
# 644    Services
# 645     Teacher
# 646       Other
# 647    Services
# 648    Services
# Name: Mjob, Length: 1044, dtype: object

# %% [markdown]
# ### 37. Capitalize both Mjob and Fjob variables using above lamdba function

# %%
df.loc[:,['Mjob','Fjob']].apply(lambda x :x.str.upper())
# Out:
#          Mjob      Fjob
# 0     AT_HOME   TEACHER
# 1     AT_HOME     OTHER
# 2     AT_HOME     OTHER
# 3      HEALTH  SERVICES
# 4       OTHER     OTHER
# ..        ...       ...
# 644  SERVICES     OTHER
# 645   TEACHER  SERVICES
# 646     OTHER     OTHER
# 647  SERVICES  SERVICES
# 648  SERVICES     OTHER
#
# [1044 rows x 2 columns]

# %% [markdown]
# ### 38. Print the last elements of the data set. (Last few records)

# %%
df.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 639     MS   M   19       R     GT3       T     1     1     other  services
# 640     MS   M   18       R     GT3       T     4     2     other     other
# 641     MS   F   18       R     GT3       T     2     2   at_home     other
# 642     MS   F   17       U     GT3       T     4     3   teacher     other
# 643     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 639  ...      4        3      2     1     3      5        0   5   8   0
# 640  ...      5        4      3     4     3      3        0   7   7   0
# 641  ...      5        3      3     1     3      4        0  14  17  15
# 642  ...      5        5      4     1     1      1        0   6   9  11
# 643  ...      4        4      3     2     2      5        4   7   9  10
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [10 rows x 33 columns]

# %% [markdown]
# ### 39. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
#Yes, its because i have not saved it.
df.loc[:,['Mjob','Fjob']]=df.loc[:,['Mjob','Fjob']].apply(lambda x :x.str.upper())
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   AT_HOME   TEACHER
# 1       GP   F   17       U     GT3       T     1     1   AT_HOME     OTHER
# 2       GP   F   15       U     LE3       T     1     1   AT_HOME     OTHER
# 3       GP   F   15       U     GT3       T     4     2    HEALTH  SERVICES
# 4       GP   F   16       U     GT3       T     3     3     OTHER     OTHER
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  SERVICES     OTHER
# 645     MS   F   18       U     LE3       T     3     1   TEACHER  SERVICES
# 646     MS   F   18       U     GT3       T     1     1     OTHER     OTHER
# 647     MS   M   17       U     LE3       T     3     1  SERVICES  SERVICES
# 648     MS   M   18       R     LE3       T     3     2  SERVICES     OTHER
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [1044 rows x 33 columns]

# %% [markdown]
# ### 40. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    return(np.where(df.age>=18,True,False))

# %%
df.loc[:,'legal_drinker']=majority(df.age)
df.loc[:,['age','legal_drinker']]
# Out:
#      age  legal_drinker
# 0     18           True
# 1     17          False
# 2     15          False
# 3     15          False
# 4     16          False
# ..   ...            ...
# 644   19           True
# 645   18           True
# 646   18           True
# 647   17          False
# 648   18           True
#
# [1044 rows x 2 columns]

# %% [markdown]
# ### 41. Multiply every number of the dataset by 10.

# %%
df.select_dtypes('number')*10
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    180    40    40          20         20         0      40        30
# 1    170    10    10          10         20         0      50        30
# 2    150    10    10          10         20        30      40        30
# 3    150    40    20          10         30         0      30        20
# 4    160    30    30          10         20         0      40        30
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 644  190    20    30          10         30        10      50        40
# 645  180    30    10          10         20         0      40        30
# 646  180    10    10          20         20         0      10        10
# 647  170    30    10          20         10         0      20        40
# 648  180    30    20          30         10         0      40        40
#
#      goout  Dalc  Walc  health  absences   G1   G2   G3
# 0       40    10    10      30        60   50   60   60
# 1       30    10    10      30        40   50   50   60
# 2       20    20    30      30       100   70   80  100
# 3       20    10    10      50        20  150  140  150
# 4       20    10    20      50        40   60  100  100
# ..     ...   ...   ...     ...       ...  ...  ...  ...
# 644     20    10    20      50        40  100  110  100
# 645     40    10    10      10        40  150  150  160
# 646     10    10    10      50        60  110  120   90
# 647     50    30    40      20        60  100  100  100
# 648     10    30    40      50        40  100  110  110
#
# [1044 rows x 16 columns]

# %% [markdown]
# ## Section-6: The purpose of the below exercises is to understand how to perform simple joins
# ## The below exercises (42-48) required to use cars1.csv and cars2.csv files

# %% [markdown]
# ### 42. Import the datasets cars1.csv and cars2.csv and assign names as cars1 and cars2

# %%
cars1=pd.read_csv('C:/users/hp/cars1.csv')
cars2=pd.read_csv('C:/users/hp/cars2.csv')

# %% [markdown]
#    ### 43. Print the information to cars1 by applying below functions
#    hint: Use different functions/methods like type(), head(), tail(), columns(), info(), dtypes(), index(), shape(), count(), size(), ndim(), axes(), describe(), memory_usage(), sort_values(), value_counts()
#    Also create profile report using pandas_profiling.Profile_Report

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.0+ KB

# %% [markdown]
# ### 44. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1=cars1.dropna(axis=1)

# %% [markdown]
# ### 45. What is the number of observations in each dataset?

# %%
cars1.count(),cars2.count()
# Out:
# (mpg             198
#  cylinders       198
#  displacement    198
#  horsepower      198
#  weight          198
#  acceleration    198
#  model           198
#  origin          198
#  car             198
#  dtype: int64,
#  mpg             200
#  cylinders       200
#  displacement    200
#  horsepower      200
#  weight          200
#  acceleration    200
#  model           200
#  origin          200
#  car             200
#  dtype: int64)

# %% [markdown]
# ### 46. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.merge(cars1,cars2,left_on='model',right_on='model',how='inner')

# %%
cars
# Out:
#      mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  \
# 0     28.0            4             107           86      2464
# 1     28.0            4             107           86      2464
# 2     28.0            4             107           86      2464
# 3     28.0            4             107           86      2464
# 4     28.0            4             107           86      2464
# ..     ...          ...             ...          ...       ...
# 283   29.0            4              90           70      1937
# 284   29.0            4              90           70      1937
# 285   29.0            4              90           70      1937
# 286   29.0            4              90           70      1937
# 287   29.0            4              90           70      1937
#
#      acceleration_x  model  origin_x      car_x  mpg_y  cylinders_y  \
# 0              15.5     76         2   fiat 131   33.0            4
# 1              15.5     76         2   fiat 131   20.0            6
# 2              15.5     76         2   fiat 131   18.0            6
# 3              15.5     76         2   fiat 131   18.5            6
# 4              15.5     76         2   fiat 131   17.5            6
# ..              ...    ...       ...        ...    ...          ...
# 283            14.2     76         2  vw rabbit   16.5            6
# 284            14.2     76         2  vw rabbit   16.5            8
# 285            14.2     76         2  vw rabbit   13.0            8
# 286            14.2     76         2  vw rabbit   13.0            8
# 287            14.2     76         2  vw rabbit   13.0            8
#
#      displacement_y horsepower_y  weight_y  acceleration_y  origin_y  \
# 0                91           53      1795            17.4         3
# 1               225          100      3651            17.7         1
# 2               250           78      3574            21.0         1
# 3               250          110      3645            16.2         1
# 4               258           95      3193            17.8         1
# ..              ...          ...       ...             ...       ...
# 283             168          120      3820            16.7         2
# 284             350          180      4380            12.1         1
# 285             350          145      4055            12.0         1
# 286             302          130      3870            15.0         1
# 287             318          150      3755            14.0         1
#
#                   car_y
# 0           honda civic
# 1        dodge aspen se
# 2     ford granada ghia
# 3    pontiac ventura sj
# 4         amc pacer d/l
# ..                  ...
# 283  mercedes-benz 280s
# 284    cadillac seville
# 285           chevy c10
# 286           ford f108
# 287          dodge d100
#
# [288 rows x 17 columns]

# %% [markdown]
# ### 47. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
cars.loc[:,'owners']=np.random.randint(15000,73000,len(cars))
cars
# Out:
#      mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  \
# 0     28.0            4             107           86      2464
# 1     28.0            4             107           86      2464
# 2     28.0            4             107           86      2464
# 3     28.0            4             107           86      2464
# 4     28.0            4             107           86      2464
# ..     ...          ...             ...          ...       ...
# 283   29.0            4              90           70      1937
# 284   29.0            4              90           70      1937
# 285   29.0            4              90           70      1937
# 286   29.0            4              90           70      1937
# 287   29.0            4              90           70      1937
#
#      acceleration_x  model  origin_x      car_x  mpg_y  cylinders_y  \
# 0              15.5     76         2   fiat 131   33.0            4
# 1              15.5     76         2   fiat 131   20.0            6
# 2              15.5     76         2   fiat 131   18.0            6
# 3              15.5     76         2   fiat 131   18.5            6
# 4              15.5     76         2   fiat 131   17.5            6
# ..              ...    ...       ...        ...    ...          ...
# 283            14.2     76         2  vw rabbit   16.5            6
# 284            14.2     76         2  vw rabbit   16.5            8
# 285            14.2     76         2  vw rabbit   13.0            8
# 286            14.2     76         2  vw rabbit   13.0            8
# 287            14.2     76         2  vw rabbit   13.0            8
#
#      displacement_y horsepower_y  weight_y  acceleration_y  origin_y  \
# 0                91           53      1795            17.4         3
# 1               225          100      3651            17.7         1
# 2               250           78      3574            21.0         1
# 3               250          110      3645            16.2         1
# 4               258           95      3193            17.8         1
# ..              ...          ...       ...             ...       ...
# 283             168          120      3820            16.7         2
# 284             350          180      4380            12.1         1
# 285             350          145      4055            12.0         1
# 286             302          130      3870            15.0         1
# 287             318          150      3755            14.0         1
#
#                   car_y  owners
# 0           honda civic   52628
# 1        dodge aspen se   40951
# 2     ford granada ghia   15240
# 3    pontiac ventura sj   68986
# 4         amc pacer d/l   40473
# ..                  ...     ...
# 283  mercedes-benz 280s   54851
# 284    cadillac seville   70882
# 285           chevy c10   23534
# 286           ford f108   36824
# 287          dodge d100   54193
#
# [288 rows x 18 columns]

# %% [markdown]
# ### 48. Add the column owners to cars

# %%
cars.loc[:,'owners']=np.random.randint(15000,73000,len(cars))
cars
# Out:
#      mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  \
# 0     28.0            4             107           86      2464
# 1     28.0            4             107           86      2464
# 2     28.0            4             107           86      2464
# 3     28.0            4             107           86      2464
# 4     28.0            4             107           86      2464
# ..     ...          ...             ...          ...       ...
# 283   29.0            4              90           70      1937
# 284   29.0            4              90           70      1937
# 285   29.0            4              90           70      1937
# 286   29.0            4              90           70      1937
# 287   29.0            4              90           70      1937
#
#      acceleration_x  model  origin_x      car_x  mpg_y  cylinders_y  \
# 0              15.5     76         2   fiat 131   33.0            4
# 1              15.5     76         2   fiat 131   20.0            6
# 2              15.5     76         2   fiat 131   18.0            6
# 3              15.5     76         2   fiat 131   18.5            6
# 4              15.5     76         2   fiat 131   17.5            6
# ..              ...    ...       ...        ...    ...          ...
# 283            14.2     76         2  vw rabbit   16.5            6
# 284            14.2     76         2  vw rabbit   16.5            8
# 285            14.2     76         2  vw rabbit   13.0            8
# 286            14.2     76         2  vw rabbit   13.0            8
# 287            14.2     76         2  vw rabbit   13.0            8
#
#      displacement_y horsepower_y  weight_y  acceleration_y  origin_y  \
# 0                91           53      1795            17.4         3
# 1               225          100      3651            17.7         1
# 2               250           78      3574            21.0         1
# 3               250          110      3645            16.2         1
# 4               258           95      3193            17.8         1
# ..              ...          ...       ...             ...       ...
# 283             168          120      3820            16.7         2
# 284             350          180      4380            12.1         1
# 285             350          145      4055            12.0         1
# 286             302          130      3870            15.0         1
# 287             318          150      3755            14.0         1
#
#                   car_y  owners
# 0           honda civic   62397
# 1        dodge aspen se   35161
# 2     ford granada ghia   68950
# 3    pontiac ventura sj   43899
# 4         amc pacer d/l   48873
# ..                  ...     ...
# 283  mercedes-benz 280s   21994
# 284    cadillac seville   63012
# 285           chevy c10   45923
# 286           ford f108   47087
# 287          dodge d100   55911
#
# [288 rows x 18 columns]

# %% [markdown]
# ## Section-7: The purpose of the below exercises is to understand how to perform date time operations

# %% [markdown]
# ### 49. Write a Python script to display the
# - a. Current date and time
# - b. Current year
# - c. Month of year
# - d. Week number of the year
# - e. Weekday of the week
# - f. Day of year
# - g. Day of the month
# - h. Day of week

# %%
#Current date and time
import datetime as dt
a=pd.Timestamp.today()
a
# Out:
# Timestamp('2022-12-02 22:53:25.673780')

# %%
#Current year
b=pd.datetime.today().year
b
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\525789221.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   b=pd.datetime.today().year
# 2022

# %%
#Month of year
c=pd.datetime.today().month
c
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\322295558.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   c=pd.datetime.today().month
# 11

# %%
#week number of the year
import datetime as dt
d=pd.datetime.today()
date=d.strftime('%d-%m-%Y')
pd.to_datetime(date).isocalendar().week
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\3648318528.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d=pd.datetime.today()
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\3648318528.py:4: UserWarning: Parsing '28-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   pd.to_datetime(date).isocalendar().week
# 48

# %%
#Weekday of the week
pd.to_datetime(date).weekday()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\3707468117.py:2: UserWarning: Parsing '28-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   pd.to_datetime(date).weekday()
# 0

# %%
#Day of year
#pd.datetime.today().day
day_of_year = pd.datetime.now().timetuple().tm_yday
print("\nDay of year: ", day_of_year, "\n")
# Out:
# Day of year:  333
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\3996354941.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   day_of_year = pd.datetime.now().timetuple().tm_yday

# %%
#Day of the month
#pd.datetime.today().day
day_of_year = pd.datetime.now().timetuple().tm_mday
print("\nmonth of year: ", day_of_year, "\n")
# Out:
# month of year:  29
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\3723486480.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   day_of_year = pd.datetime.now().timetuple().tm_mday

# %%
#Day of week
day_of_year = pd.datetime.now().timetuple().tm_wday
print("\nDay of week: ", day_of_year, "\n")
# Out:
# Day of week:  1
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\1637610297.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   day_of_year = pd.datetime.now().timetuple().tm_wday

# %% [markdown]
# ### 50. Write a Python program to convert a string to datetime.
# Sample String : Jul 1 2014 2:43PM
#
# Expected Output : 2014-07-01 14:43:00

# %%
## string= pd.to_datetime(Jul ,1, 2014 ,2:43PM )
pd.to_datetime('Jul 1 2014 2:43PM',format='%b %d %Y %I:%M%p')
# Out:
# Timestamp('2014-07-01 14:43:00')

# %% [markdown]
# ### 51. Write a Python program to subtract five days from current date.
#
# Current Date : 2015-06-22
#
# 5 days before Current Date : 2015-06-17

# %%
cdate=pd.datetime(2015,6,22)
sdate=cdate-pd.DateOffset(days=5)
sdate
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11956\3815249234.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   cdate=pd.datetime(2015,6,22)
# Timestamp('2015-06-17 00:00:00')

# %% [markdown]
# ### 52. Write a Python program to convert unix timestamp string to readable date.
#
# Sample Unix timestamp string : 1284105682
#
# Expected Output : 2010-09-10 13:31:22

# %%
ts=int('1284105682')
date=pd.datetime.utcfromtimestamp(ts)
date.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1688\2048951414.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date=pd.datetime.utcfromtimestamp(ts)
# '2010-09-10 08:01:22'

# %% [markdown]
# ### 53. Convert the below Series to pandas datetime :
#
# DoB = pd.Series(["07Sep59","01Jan55","15Dec47","11Jul42"])
#
# Make sure that the year is 19XX not 20XX

# %%
#DoB = pd.Series(["07Sep59","01Jan55","15Dec47","11Jul42"])
#DoB=pd.to_datetime(DoB)
#print(calendar.timegmt.timetuple())

DoB = pd.Series(["07Sep59","01Jan55","15Dec47","11Jul42"])
pd.to_datetime(DoB, format='%d%b%y')
# Out:
# 0   2059-09-07
# 1   2055-01-01
# 2   2047-12-15
# 3   2042-07-11
# dtype: datetime64[ns]

# %% [markdown]
# ### 54. Write a Python program to get days between two dates.

# %%
d1=pd.to_datetime('13-09-1993')
d2=pd.to_datetime('29-11-2022')
d=d2-d1
d
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1688\2707197435.py:1: UserWarning: Parsing '13-09-1993' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   d1=pd.to_datetime('13-09-1993')
# C:\Users\hp\AppData\Local\Temp\ipykernel_1688\2707197435.py:2: UserWarning: Parsing '29-11-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   d2=pd.to_datetime('29-11-2022')
# Timedelta('10669 days 00:00:00')

# %% [markdown]
# ### 55. Convert the below date to datetime and then change its display format using the .dt module
#
# Date = "15Dec1989"
#
# Result : "Friday, 15 Dec 98"

# %%
Date1=pd.to_datetime('15Dec1989',format='%d%b%Y')
Date1.strftime('%A, %d %b %y')
# Out:
# 'Friday, 15 Dec 89'

# %% [markdown]
# ## The below exercises (56-66) required to use wind.data file

# %% [markdown]
# ### About wind.data:
#
# The data have been modified to contain some missing values, identified by NaN.
#
# 1. The data in 'wind.data' has the following format:

# %% [raw]
# """
# Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
# 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
# """
# The first three columns are year, month and day.  The remaining 12 columns are average windspeeds in knots at 12 locations in Ireland on that day.

# %% [markdown]
# ### 56. Import the dataset wind.data and assign it to a variable called data and replace the first 3 columns by a proper date time index

# %%
data=pd.read_csv('C:/users/hp/wind.data')
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 15 columns]

# %%
data.insert(0,'date',data.Yr.astype(str)+'-'+data.Mo.astype(str)+'-'+data.Dy.astype(str))

# %%
data
# Out:
#           date  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# 0       61-1-1  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67
# 1       61-1-2  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50
# 2       61-1-3  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25
# 3       61-1-4  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63
# 4       61-1-5  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92
# ...        ...  ..  ..  ..    ...    ...    ...    ...    ...    ...    ...
# 6569  78-12-27  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46
# 6570  78-12-28  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33
# 6571  78-12-29  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17
# 6572  78-12-30  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08
# 6573  78-12-31  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25
#
#         CLA    MUL    CLO    BEL    MAL
# 0     10.25  10.83  12.58  18.50  15.04
# 1     10.04   9.79   9.67  17.54  13.83
# 2       NaN   8.50   7.67  12.75  12.71
# 3      1.79   5.83   5.88   5.46  10.88
# 4      6.54  10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...    ...
# 6569  15.59  14.04  14.00  17.21  40.08
# 6570  16.25  15.25  18.05  21.79  41.46
# 6571  12.46  14.50  16.42  18.88  29.58
# 6572  12.87  12.46  12.12  14.67  28.79
# 6573  11.63  11.58  11.38  12.08  22.08
#
# [6574 rows x 16 columns]

# %% [markdown]
# ### 57. Year 2061 is seemingly imporoper. Convert every year which are < 70 to 19XX instead of 20XX.

# %%
np.where(data.Yr<70,'19'+data.Yr.astype(str),'19'+data.Yr.astype(str))
# Out:
# array(['1961', '1961', '1961', ..., '1978', '1978', '1978'], dtype=object)

# %%
data.insert(1,'Year',np.where(data.Yr<70,'19'+data.Yr.astype(str),'19'+data.Yr.astype(str)))

# %%
data
# Out:
#           date  Year  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR  \
# 0       61-1-1  1961  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87
# 1       61-1-2  1961  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67
# 2       61-1-3  1961  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17
# 3       61-1-4  1961  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88
# 4       61-1-5  1961  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21
# ...        ...   ...  ..  ..  ..    ...    ...    ...    ...    ...    ...
# 6569  78-12-27  1978  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67
# 6570  78-12-28  1978  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42
# 6571  78-12-29  1978  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54
# 6572  78-12-30  1978  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71
# 6573  78-12-31  1978  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13
#
#         DUB    CLA    MUL    CLO    BEL    MAL
# 0     13.67  10.25  10.83  12.58  18.50  15.04
# 1     11.50  10.04   9.79   9.67  17.54  13.83
# 2     11.25    NaN   8.50   7.67  12.75  12.71
# 3      8.63   1.79   5.83   5.88   5.46  10.88
# 4     11.92   6.54  10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...    ...    ...
# 6569  14.46  15.59  14.04  14.00  17.21  40.08
# 6570  14.33  16.25  15.25  18.05  21.79  41.46
# 6571  19.17  12.46  14.50  16.42  18.88  29.58
# 6572  18.08  12.87  12.46  12.12  14.67  28.79
# 6573  19.25  11.63  11.58  11.38  12.08  22.08
#
# [6574 rows x 17 columns]

# %%
data.drop(columns=['date','Yr'])
# Out:
#       Year  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     1961   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     1961   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     1961   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     1961   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     1961   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...    ...  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  1978  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  1978  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  1978  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  1978  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  1978  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 15 columns]

# %% [markdown]
# ### 58. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.loc[:,'date']=data.Year.astype(str)+'-'+data.Mo.astype(str)+'-'+data.Dy.astype(str)

# %%
data
# Out:
#             date  Year  Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR  \
# 0       1961-1-1  1961  61   1   1  15.04  14.96  13.17   9.29    NaN   9.87
# 1       1961-1-2  1961  61   1   2  14.71    NaN  10.83   6.50  12.62   7.67
# 2       1961-1-3  1961  61   1   3  18.50  16.88  12.33  10.13  11.17   6.17
# 3       1961-1-4  1961  61   1   4  10.58   6.63  11.75   4.58   4.54   2.88
# 4       1961-1-5  1961  61   1   5  13.33  13.25  11.42   6.17  10.71   8.21
# ...          ...   ...  ..  ..  ..    ...    ...    ...    ...    ...    ...
# 6569  1978-12-27  1978  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67
# 6570  1978-12-28  1978  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42
# 6571  1978-12-29  1978  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54
# 6572  1978-12-30  1978  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71
# 6573  1978-12-31  1978  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13
#
#         DUB    CLA    MUL    CLO    BEL    MAL
# 0     13.67  10.25  10.83  12.58  18.50  15.04
# 1     11.50  10.04   9.79   9.67  17.54  13.83
# 2     11.25    NaN   8.50   7.67  12.75  12.71
# 3      8.63   1.79   5.83   5.88   5.46  10.88
# 4     11.92   6.54  10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...    ...    ...
# 6569  14.46  15.59  14.04  14.00  17.21  40.08
# 6570  14.33  16.25  15.25  18.05  21.79  41.46
# 6571  19.17  12.46  14.50  16.42  18.88  29.58
# 6572  18.08  12.87  12.46  12.12  14.67  28.79
# 6573  19.25  11.63  11.58  11.38  12.08  22.08
#
# [6574 rows x 17 columns]

# %%
data.set_index('date',inplace=True)

# %%
data=data.drop(columns=['Yr','Mo','Dy','Year'])

# %%
data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# date
# 1961-1-1    15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-1-2    14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-1-3    18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-1-4    10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-1-5    13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# date
# 1961-1-1    12.58  18.50  15.04
# 1961-1-2     9.67  17.54  13.83
# 1961-1-3     7.67  12.75  12.71
# 1961-1-4     5.88   5.46  10.88
# 1961-1-5    10.34  12.92  11.83
# ...           ...    ...    ...
# 1978-12-27  14.00  17.21  40.08
# 1978-12-28  18.05  21.79  41.46
# 1978-12-29  16.42  18.88  29.58
# 1978-12-30  12.12  14.67  28.79
# 1978-12-31  11.38  12.08  22.08
#
# [6574 rows x 12 columns]

# %% [markdown]
# ### 59. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### 60. Compute how many non-missing values there are in total.

# %%
#data.shape[0]-data.isnull().sum()
#OR
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### 61. Calculate the mean windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
(data.sum().sum())/(data.notnull().sum().sum())
# Out:
# 10.227883764282181

# %% [markdown]
# ### 62. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=pd.DataFrame(data.select_dtypes('number').describe(percentiles=[]))
loc_stats
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 50%       6.830000     9.210000     8.080000     8.170000     8.290000
# max      26.160000    30.370000    31.080000    25.880000    28.210000
#
#                BEL          MAL
# count  6574.000000  6570.000000
# mean     13.121007    15.599079
# std       5.835037     6.699794
# min       0.130000     0.670000
# 50%      12.500000    15.000000
# max      42.380000    42.540000

# %% [markdown]
# ### 63. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats=pd.DataFrame

# %%
day_stats=data.agg(['min','max','mean','std'],axis=1)
day_stats
# Out:
#              min    max       mean       std
# date
# 1961-1-1    9.29  18.50  13.018182  2.808875
# 1961-1-2    6.50  17.54  11.336364  3.188994
# 1961-1-3    6.17  18.50  11.641818  3.681912
# 1961-1-4    1.79  11.75   6.619167  3.198126
# 1961-1-5    6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# ### 64. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data.loc[(data.index>='1961-1-1') & (data.index<='1962-1-31')].mean()
# Out:
# RPT    12.494208
# VAL    10.556512
# ROS    11.455851
# KIL     7.026166
# SHA    10.955232
# BIR     7.810462
# DUB    10.045762
# CLA     8.920438
# MUL     8.741370
# CLO     9.951234
# BEL    13.667436
# MAL    13.805401
# dtype: float64

# %% [markdown]
# ### 65. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
data.groupby(pd.to_datetime((data.index),format='%Y-%m-%d').month)[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].mean()
# Out:
#             RPT        VAL        ROS       KIL        SHA       BIR  \
# date
# 1     14.847325  12.914560  13.299624  7.199498  11.667734  8.054839
# 2     13.710906  12.111122  12.879132  6.942411  11.551772  7.633858
# 3     13.158687  11.505842  12.648118  7.265907  11.554516  7.959409
# 4     12.555648  10.429759  12.204815  6.898037  10.677667  7.441389
# 5     11.724032  10.145619  11.550394  6.307487  10.224301  6.942061
# 6     10.451317   8.949704  10.361315  5.652278   9.529926  6.410093
# 7      9.992007   8.357778   9.349642  5.416935   9.302634  5.972348
# 8     10.213411   8.415143   9.993441  5.270681   8.901559  5.891057
# 9     11.458519   9.981002  10.756883  5.615176   9.766315  6.566222
# 10    12.660610  11.010681  11.453943  6.065215  10.550251  7.159910
# 11    13.200722  11.639500  12.293407  6.247611  10.501130  7.134333
# 12    14.446398  12.353602  13.212276  6.829910  11.301254  7.963710
#
#             DUB       CLA       MUL        CLO        BEL        MAL
# date
# 1     11.819355  9.512047  9.543208  10.053566  14.550520  18.028763
# 2     11.206024  9.341437  9.313169   9.518051  13.728898  17.156142
# 3     11.310179  9.635896  9.700324  10.096953  13.810609  16.909317
# 4     10.221315  8.909056  8.930870   9.158019  12.664759  14.937611
# 5      8.797738  8.452903  8.040806   8.524857  12.767258  13.736039
# 6      8.009556  7.920796  7.639796   7.729185  12.246407  12.861818
# 7      7.843501  7.262760  7.544480   7.321416  11.676505  12.800789
# 8      7.772312  6.842025  7.240573   7.002783  11.110090  12.565943
# 9      8.609722  7.745677  7.610556   7.689278  12.686389  14.761963
# 10     9.387778  8.726308  8.347181   8.850376  14.155323  16.697151
# 11    10.814861  8.427167  8.604000   8.943167  13.815741  18.114185
# 12    11.849050  9.209355  9.447258   9.627670  14.259516  18.697599

# %% [markdown]
# ### 66. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
data.groupby(pd.to_datetime((data.index),format='%Y-%m-%d').isocalendar().week)[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].agg(['min','max','mean','std'],axis=1)
# Out:
#        RPT                               VAL                              \
#        min    max       mean       std   min    max       mean       std
# week
# 1     2.62  33.34  13.920000  6.341312  0.54  28.50  11.710880  5.976741
# 2     2.00  32.17  15.549921  6.493246  1.08  33.04  13.359524  6.445335
# 3     1.63  33.12  14.950159  6.323325  1.50  26.54  13.281349  5.487427
# 4     0.67  35.38  15.241920  6.558873  2.83  29.88  13.575317  6.062601
# 5     2.71  33.84  14.559127  5.712026  1.17  26.38  12.853413  5.947208
# 6     2.79  30.13  13.203730  5.620867  0.79  30.96  11.508492  5.845671
# 7     2.92  29.17  14.517460  5.916627  2.67  28.16  12.681349  5.974678
# 8     1.54  32.38  13.422857  5.923096  0.63  29.33  11.822937  5.428889
# 9     0.67  28.91  12.761360  5.240324  1.42  25.66  11.837460  5.206450
# 10    2.29  35.80  13.526720  6.165086  1.50  31.63  11.758095  5.842768
# 11    1.46  33.04  13.597143  6.412912  1.58  28.46  11.495079  5.553335
# 12    2.92  32.13  13.006825  5.509073  2.25  23.29  11.621032  5.109913
# 13    2.79  27.12  12.772540  5.278774  1.54  24.67  11.076349  5.126852
# 14    3.88  32.58  13.903968  5.698092  1.87  27.58  11.025238  5.048327
# 15    4.42  29.79  12.599444  5.335705  1.63  26.96   9.966667  4.679762
# 16    3.67  27.84  12.753968  5.248461  0.54  27.71  11.111587  5.032893
# 17    3.46  26.83  10.966349  5.378706  1.42  23.16   9.647698  4.758561
# 18    1.63  27.25  12.897222  4.367054  2.96  21.84  11.095079  4.274369
# 19    3.54  30.91  13.061429  5.517038  1.83  22.17  11.275159  4.345500
# 20    2.42  25.17  11.338571  5.404169  1.63  22.95   9.769200  4.876184
# 21    2.62  28.79  11.282698  5.200316  1.25  26.00   9.673889  4.471767
# 22    2.04  21.84   9.673333  4.053188  2.21  19.55   8.264683  3.521804
# 23    2.17  23.21  10.092143  4.516349  1.83  18.71   8.980556  3.909693
# 24    1.00  21.59  10.131905  4.410570  1.71  19.33   8.741984  4.503438
# 25    2.92  22.71  11.680238  4.415008  1.79  21.04   9.898016  4.116320
# 26    3.46  20.50  10.036000  3.868826  1.79  17.46   8.770635  3.476639
# 27    2.00  25.84   9.991984  4.742847  1.00  18.08   7.916984  3.715586
# 28    2.75  22.50   9.962143  4.661313  1.96  19.29   8.272619  3.932700
# 29    1.71  22.34  10.281746  4.578130  0.96  18.54   8.422063  3.921746
# 30    1.25  20.33   9.760397  4.056483  2.08  16.29   8.211984  3.535041
# 31    2.79  22.42   9.721984  4.143365  0.71  19.41   8.218571  3.691241
# 32    2.67  20.08  10.202640  3.982815  1.17  17.62   8.669683  4.076909
# 33    3.17  26.38  10.213254  4.914926  1.46  23.42   8.000476  4.180112
# 34    2.42  24.67  10.675556  4.874965  0.83  20.12   9.065317  4.372665
# 35    0.96  23.38  10.378571  4.976603  1.13  23.54   8.525476  4.816354
# 36    1.50  29.54  10.764365  5.086312  0.83  22.79   9.296190  4.585837
# 37    1.79  31.42  11.371190  5.662910  1.75  28.50   9.722857  4.902647
# 38    0.79  24.79   9.929524  4.585719  0.87  23.09   8.863095  4.646788
# 39    3.37  27.00  13.960635  5.313510  1.38  25.08  12.361920  4.898134
# 40    2.37  25.29  12.199841  4.458238  0.75  24.17  10.619127  4.799801
# 41    3.04  25.92  12.260800  5.400736  0.21  22.83  10.581508  5.352465
# 42    2.04  28.62  12.777460  5.718162  1.21  23.58  10.966587  5.149048
# 43    1.50  29.08  13.358651  6.116732  1.21  26.71  11.915238  5.455591
# 44    3.67  30.09  13.338254  4.922444  1.79  24.87  11.704444  4.971470
# 45    2.96  32.96  13.292857  5.696753  1.92  30.34  11.758968  5.684442
# 46    3.50  30.21  14.081746  6.390996  1.75  27.63  12.423571  6.101791
# 47    2.67  26.50  11.731508  5.234852  1.21  26.46  10.361667  5.278304
# 48    3.08  34.37  13.843413  6.318558  1.46  33.37  12.230159  6.361247
# 49    1.21  29.33  14.685000  5.664730  0.42  24.79  12.947222  5.343695
# 50    1.96  30.91  14.462619  6.921477  0.75  25.17  12.462619  6.260802
# 51    1.79  28.71  13.639921  5.313674  0.54  29.38  11.697619  5.537990
# 52    3.00  32.50  14.469134  5.701056  1.46  26.54  11.692283  5.488104
# 53    3.71  23.83  12.694286  5.804934  0.37  24.17   9.451905  6.491561
#
#        ROS         ...        CLO             BEL                              \
#        min    max  ...       mean       std   min    max       mean       std
# week               ...
# 1     3.79  28.67  ...   9.870635  5.290276  0.58  38.20  14.241746  7.140370
# 2     3.54  26.67  ...   9.798175  5.275913  1.71  39.04  14.494603  7.201756
# 3     3.00  32.25  ...  10.169444  4.775379  1.87  29.42  14.578254  5.621603
# 4     2.75  28.08  ...  10.352063  5.188772  0.13  34.42  14.892222  7.048260
# 5     3.21  28.16  ...  10.196111  4.991521  1.96  27.71  14.667381  6.457600
# 6     3.67  28.75  ...   9.298175  4.624377  2.04  28.12  13.903254  6.420629
# 7     3.50  28.96  ...   9.605476  5.241451  2.67  32.08  13.776667  6.656479
# 8     2.37  32.71  ...   9.541984  5.096524  2.17  35.08  13.132302  6.070031
# 9     2.50  28.42  ...   9.611508  4.548139  2.13  31.13  13.724048  6.613164
# 10    3.42  32.75  ...   9.761429  4.978696  2.21  32.63  13.055000  6.240588
# 11    2.92  31.83  ...  10.398730  5.112287  2.25  34.92  13.823968  6.768240
# 12    3.17  30.84  ...  10.259048  4.517893  2.96  31.71  14.389524  5.967105
# 13    2.71  24.08  ...  10.038571  4.379889  2.50  32.21  14.241667  5.666283
# 14    3.04  29.04  ...   9.948175  4.384778  2.88  25.50  13.386270  5.398770
# 15    1.75  30.54  ...   9.338413  4.272218  4.46  27.00  12.842460  4.996957
# 16    3.33  27.04  ...   9.326905  4.220644  3.21  23.96  12.472857  5.012081
# 17    2.54  29.79  ...   8.238333  4.217093  3.75  26.12  11.971667  5.180717
# 18    3.58  21.21  ...   8.952857  4.082519  3.29  28.33  12.928968  5.451848
# 19    2.29  27.67  ...   9.243254  4.348034  4.71  32.91  13.721984  5.172165
# 20    3.46  23.25  ...   8.507540  4.520118  4.12  26.42  12.740952  5.203613
# 21    3.04  26.20  ...   8.278413  3.691034  3.21  28.12  12.536270  4.948721
# 22    3.50  25.50  ...   7.247222  3.354776  2.67  26.38  11.238810  4.550995
# 23    2.75  27.25  ...   7.173810  3.366850  4.04  21.34  11.605635  4.118631
# 24    1.87  28.58  ...   7.259524  3.994689  3.08  25.25  11.835873  5.061491
# 25    4.21  22.54  ...   8.677063  4.260790  2.96  29.79  13.494762  4.703843
# 26    1.83  19.00  ...   7.937778  3.233524  4.21  24.71  12.462222  4.694937
# 27    2.83  20.33  ...   7.451349  3.720332  4.04  23.00  11.582857  4.091140
# 28    3.42  22.04  ...   7.267063  3.662487  3.25  23.83  11.450159  4.626530
# 29    2.92  23.00  ...   7.616349  3.733708  3.33  24.41  12.021667  4.682591
# 30    2.50  25.12  ...   7.010317  3.470866  3.58  22.37  11.410794  4.371903
# 31    3.08  21.42  ...   6.615556  3.502351  3.46  21.67  11.020317  4.278601
# 32    4.21  21.62  ...   7.057840  3.676547  3.29  24.08  11.154365  4.323404
# 33    2.92  27.88  ...   6.502460  4.084187  1.58  23.25  10.647222  4.965292
# 34    3.54  19.83  ...   7.779206  4.206738  1.63  24.83  11.881667  5.508187
# 35    2.42  20.75  ...   7.213175  4.115397  2.67  26.46  11.606825  5.625526
# 36    2.29  23.21  ...   7.221905  3.713513  1.63  24.17  11.597619  4.557266
# 37    2.96  31.63  ...   7.645952  4.671456  2.54  25.75  12.658968  5.426080
# 38    2.37  22.54  ...   6.423095  3.609957  2.79  23.04  11.394127  4.955622
# 39    2.25  22.95  ...   9.402540  4.402953  2.21  28.79  14.980000  6.182079
# 40    2.54  29.54  ...   8.519524  3.747967  2.42  26.71  13.326429  5.946722
# 41    2.37  22.63  ...   8.176825  4.367278  2.54  34.83  13.550952  6.480897
# 42    1.96  26.83  ...   9.039286  4.454747  3.37  32.63  14.088175  6.166586
# 43    2.17  25.12  ...   9.800873  4.621225  2.96  38.96  16.055873  6.493643
# 44    2.37  27.37  ...   9.427222  4.226817  3.50  35.30  14.410079  6.097324
# 45    3.83  26.67  ...   8.962302  4.307786  1.50  33.34  13.990317  6.360937
# 46    1.83  33.25  ...   9.487302  5.307624  0.71  31.96  14.063889  6.764883
# 47    1.50  28.21  ...   7.933095  4.176509  1.25  30.00  12.399762  5.642172
# 48    3.21  28.46  ...   9.121190  4.994491  2.46  42.38  14.481111  6.569081
# 49    4.46  27.67  ...   9.994524  4.072104  4.04  28.16  15.140397  5.366918
# 50    2.83  25.29  ...   9.842698  5.535018  2.29  29.25  14.716905  6.919748
# 51    3.92  27.54  ...   8.687937  4.269109  2.88  30.84  13.298889  6.342417
# 52    2.13  33.84  ...   9.677953  4.510556  0.67  31.25  13.549055  6.384876
# 53    4.71  28.29  ...   7.820952  4.992835  3.00  30.46  11.028095  7.072200
#
#        MAL
#        min    max       mean       std
# week
# 1     4.17  37.63  18.249841  7.047385
# 2     3.63  34.70  17.623413  7.145932
# 3     4.63  32.83  17.981190  6.624527
# 4     3.25  40.12  18.337381  7.634472
# 5     4.83  38.79  17.702222  6.620860
# 6     5.29  33.04  17.921587  6.092634
# 7     5.09  37.04  17.130159  6.819665
# 8     3.04  38.20  16.882540  7.251216
# 9     3.17  31.66  16.602080  6.191920
# 10    2.46  37.59  16.047381  6.572057
# 11    4.54  40.37  17.331280  7.428510
# 12    3.21  37.99  17.859365  6.902719
# 13    2.04  31.20  16.486508  6.644671
# 14    3.71  34.08  16.691349  6.979889
# 15    4.33  33.95  15.900476  6.795427
# 16    4.17  28.67  14.229524  5.328738
# 17    2.21  32.05  13.097460  6.018248
# 18    2.58  28.75  14.523810  6.216011
# 19    3.33  26.83  14.288016  5.699596
# 20    3.58  32.17  13.859286  5.865042
# 21    4.04  29.50  13.626825  5.258812
# 22    1.75  28.04  11.770317  5.001233
# 23    2.21  32.79  12.395476  5.383357
# 24    2.79  27.16  12.041270  5.419266
# 25    3.08  28.38  14.329841  5.873487
# 26    4.54  25.17  12.993840  4.516285
# 27    4.50  29.63  13.096984  5.292558
# 28    2.13  28.46  12.932460  5.565273
# 29    2.29  25.37  12.880476  5.472898
# 30    2.88  25.37  12.279683  5.055287
# 31    2.25  24.83  12.348492  5.053851
# 32    3.04  29.95  12.746587  5.353812
# 33    2.17  34.33  11.315680  5.587084
# 34    3.37  30.46  13.764762  5.642352
# 35    3.83  28.84  13.390873  5.962103
# 36    3.37  30.34  13.754921  5.692819
# 37    2.83  35.13  14.827540  6.350553
# 38    0.67  29.63  13.094921  5.420672
# 39    4.04  33.63  16.928095  6.943457
# 40    2.04  32.96  15.758095  6.364950
# 41    3.33  36.51  15.663571  6.537501
# 42    5.04  33.45  17.116111  6.401907
# 43    6.17  36.63  18.580952  6.799425
# 44    6.17  37.59  18.089048  6.808701
# 45    2.96  38.04  18.065794  7.460630
# 46    2.00  41.25  19.360873  8.594056
# 47    4.25  34.83  16.473254  6.677397
# 48    5.88  42.54  18.234365  6.763319
# 49    5.09  36.08  19.625714  6.191738
# 50    6.50  37.12  18.242937  6.607478
# 51    2.62  38.25  17.182063  6.303056
# 52    4.58  41.46  19.183228  6.834899
# 53    7.12  26.83  17.103810  5.909188
#
# [53 rows x 48 columns]

# %% [markdown]
# ## The below exercises (67-70) required to use appl_1980_2014.csv  file

# %%
pd.read_csv('C:/users/hp/appl_1980_2014.csv')
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### 67. Import the file appl_1980_2014.csv and assign it to a variable called 'apple'

# %%
apple=pd.read_csv('C:/users/hp/appl_1980_2014.csv')

# %% [markdown]
# ### 68.  Check out the type of the columns

# %%
apple.columns.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### 69. Transform the Date column as a datetime type

# %%
apple['Date']=pd.to_datetime(apple['Date'])

# %%
apple['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### 70.  Set the date as the index

# %%
apple.set_index('Date',inplace=True)

# %%
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### 71.  Is there any duplicate dates?

# %%
apple.isnull().count()  # no duplicate dates is there
# Out:
# Open         8465
# High         8465
# Low          8465
# Close        8465
# Volume       8465
# Adj Close    8465
# dtype: int64

# %% [markdown]
# ### 72.  The index is from the most recent date. Sort the data so that the first entry is the oldest date.

# %%
apple.sort_index(axis=0)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...           ...    ...    ...    ...        ...        ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### 73. Get the last business day of each month

# %%
apple.loc[:,'M']=pd.to_datetime(apple.Date).dt.month

# %%
apple.loc[:,'D']=pd.to_datetime(apple.Date).dt.day

# %%
apple.groupby('M')['D'].max()
# Out:
# M
# 1     31
# 2     29
# 3     31
# 4     30
# 5     31
# 6     30
# 7     31
# 8     31
# 9     30
# 10    31
# 11    30
# 12    31
# Name: D, dtype: int64

# %% [markdown]
# ### 74.  What is the difference in days between the first day and the oldest

# %%
fdate=apple.head(1).index

# %%
ldate=apple.tail(1).index

# %%
(fdate-ldate)
# Out:
# TimedeltaIndex(['12261 days'], dtype='timedelta64[ns]', name='Date', freq=None)

# %% [markdown]
# ### 75.  How many months in the data we have?

# %%
pd.to_datetime(apple.Date).dt.month.count()
# Out:
# 8465

# %% [markdown]
# ## Section-8: The purpose of the below exercises is to understand how to create basic graphs

# %% [markdown]
# ### 76. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
apple
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close   M   D
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35   7   8
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97   7   7
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03   7   3
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48   7   2
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52   7   1
# ...          ...    ...    ...    ...    ...        ...        ...  ..  ..
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41  12  18
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40  12  17
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39  12  16
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42  12  15
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45  12  12
#
# [8465 rows x 9 columns]

# %%
plt.figure(figsize=(13.5, 9))
plt.hist(apple.loc[:,'Adj Close'])
# Out:
# (array([6451.,  543.,  375.,  142.,  185.,  164.,  151.,  202.,  175.,
#           77.]),
#  array([ 0.17 ,  9.781, 19.392, 29.003, 38.614, 48.225, 57.836, 67.447,
#         77.058, 86.669, 96.28 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## The below exercises (77-80) required to use Online_Retail.csv file

# %% [markdown]
# ### 77. Import the dataset from this Online_Retail.csv and assign it to a variable called online_rt

# %%
online_rt=pd.read_csv('C:/users/hp/Online_Retail.csv',encoding='windows-1254')
online_rt
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/10 8:26       2.55     17850.0  United Kingdom
# 1        12/1/10 8:26       3.39     17850.0  United Kingdom
# 2        12/1/10 8:26       2.75     17850.0  United Kingdom
# 3        12/1/10 8:26       3.39     17850.0  United Kingdom
# 4        12/1/10 8:26       3.39     17850.0  United Kingdom
# ...               ...        ...         ...             ...
# 541904  12/9/11 12:50       0.85     12680.0          France
# 541905  12/9/11 12:50       2.10     12680.0          France
# 541906  12/9/11 12:50       4.15     12680.0          France
# 541907  12/9/11 12:50       4.15     12680.0          France
# 541908  12/9/11 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### 78. Create a barchart with the 10 countries that have the most 'Quantity' ordered except UK

# %%
ctr=online_rt.pivot_table(index='Country',values='Quantity',aggfunc='sum').sort_values(by='Quantity',ascending=False)
ctrgraph=ctr.iloc[1:11,:].plot(kind='bar')
plt.ylabel('SumofQuantity')
plt.title('CountryVsQuantity')
plt.show()

# %% [markdown]
# ### 79.  Exclude negative Quatity entries

# %%
ctr.loc[ctr.Quantity>0]
# Out:
#                       Quantity
# Country
# United Kingdom         4263829
# Netherlands             200128
# EIRE                    142637
# Germany                 117448
# France                  110480
# Australia                83653
# Sweden                   35637
# Switzerland              30325
# Spain                    26824
# Japan                    25218
# Belgium                  23152
# Norway                   19247
# Portugal                 16180
# Finland                  10666
# Channel Islands           9479
# Denmark                   8188
# Italy                     7999
# Cyprus                    6317
# Singapore                 5234
# Austria                   4827
# Hong Kong                 4769
# Israel                    4353
# Poland                    3653
# Unspecified               3300
# Canada                    2763
# Iceland                   2458
# Greece                    1556
# USA                       1034
# United Arab Emirates       982
# Malta                      944
# Lithuania                  652
# Czech Republic             592
# European Community         497
# Lebanon                    386
# Brazil                     356
# RSA                        352
# Bahrain                    260
# Saudi Arabia                75

# %% [markdown]
# ### 80. Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries
# Hint: First we need to find top-3 countries based on revenue, then create scater plot between Quantity and Unitprice for each country separately

# %%
sc=online_rt.pivot_table(index='Country',values=['UnitPrice','Quantity'],aggfunc='sum').sort_values(by='UnitPrice',ascending=False).head(3)

# %%
sc
# Out:
#                 Quantity    UnitPrice
# Country
# United Kingdom   4263829  2245715.474
# EIRE              142637    48447.190
# France            110480    43031.990

# %%
online_rt[online_rt.Country == 'United Kingdom'].plot(kind='scatter', x='Quantity', y='UnitPrice')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Quantity', ylabel='UnitPrice'>

# %%
online_rt[online_rt.Country == 'EIRE'].plot(kind='scatter', x='Quantity', y='UnitPrice')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Quantity', ylabel='UnitPrice'>

# %%
online_rt[online_rt.Country == 'France'].plot(kind='scatter', x='Quantity', y='UnitPrice')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Quantity', ylabel='UnitPrice'>

# %% [markdown]
# ## The below exercises (81-90) required to use FMCG_Company_Data_2019.csv file

# %%
pd.read_csv('C:/users/hp/FMCG_Company_Data_2019.csv')
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
#     Total_Units  Total_Revenue  Total_Profit
# 0         21100        3584890        211000
# 1         18330        2864979        183300
# 2         22470        4058082        224700
# 3         22270        2890646        222700
# 4         20960        2997280        209600
# 5         20140        2857866        201400
# 6         29550        5735655        295500
# 7         36140        5196932        361400
# 8         23400        3060720        234000
# 9         26670        4661916        266700
# 10        41280        6794688        412800
# 11        30020        3770512        300200

# %% [markdown]
# ### 81. Import the dataset FMCG_Company_Data_2019.csv and assign it to a variable called company_data

# %%
company_data=pd.read_csv('C:/users/hp/FMCG_Company_Data_2019.csv')

# %% [markdown]
# ### 82. Create line chart for Total Revenue of all months with following properties
# - X label name = Month
# - Y label name = Total Revenue

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x=company_data.Month,y=company_data.Total_Revenue)
plt.show()

# %% [markdown]
# ### 83. Create line chart for Total Units of all months with following properties
# - X label name = Month
# - Y label name = Total Units
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x=company_data.Month,y=company_data.Total_Units,color='r')
plt.show()

# %% [markdown]
# ### 84. Read all product sales data (Facecream, FaceWash, Toothpaste, Soap, Shampo, Moisturizer) and show it  using a multiline plot
# - Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
company_data
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
#     Total_Units  Total_Revenue  Total_Profit
# 0         21100        3584890        211000
# 1         18330        2864979        183300
# 2         22470        4058082        224700
# 3         22270        2890646        222700
# 4         20960        2997280        209600
# 5         20140        2857866        201400
# 6         29550        5735655        295500
# 7         36140        5196932        361400
# 8         23400        3060720        234000
# 9         26670        4661916        266700
# 10        41280        6794688        412800
# 11        30020        3770512        300200

# %%
company_data.set_index('Month')[['FaceCream','FaceWash','ToothPaste','Soap','Shampo','Moisturizer']].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ### 85. Create Bar Chart for soap of all months and Save the chart in folder

# %%
summ=company_data.pivot_table(index='Month',values='Soap',aggfunc='sum')
summ.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ### 86. Create Stacked Bar Chart for Soap, Shampo, ToothPaste for each month
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
stack=company_data.pivot_table(index='Month',values=['Soap','Shampo','ToothPaste'],aggfunc='sum')
stack.plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ### 87. Create Histogram for Total Revenue

# %%
histo=company_data.pivot_table(index='Month',values='Total_Revenue',aggfunc='sum')
histo.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### 88. Calculate total sales data (quantity) for 2019 for each product and show it using a Pie chart. Understand percentage contribution from each product

# %%
p1=company_data.loc[:,['FaceCream','FaceWash','ToothPaste','Soap','Shampo','Moisturizer']].sum()
p2=p1.sum()
p=round(p1/p2*100,2)
p.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# ### 89. Create line plots for Soap & Facewash of all months in a single plot using Subplot

# %%
sub=company_data.loc[:,['Soap','FaceWash']]
sub.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 90. Create Box Plot for Total Profit variable

# %%
company_data.Total_Profit.plot(kind='box')
# Out:
# <AxesSubplot:>
